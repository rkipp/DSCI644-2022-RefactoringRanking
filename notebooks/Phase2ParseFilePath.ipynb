# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# change this to point to wherever you've put the data
data_dir = "F:\\GoogleDrive\\ds_ml\\RIT\\2022-01 DSCI.644\\project\\phase2\\"
data_path = data_dir + "project3-authors.csv"
df_raw = pd.read_csv(data_path)
# df_raw.shape   # (17317, 9)
# df_raw.columns # ['Name', 'CommitId', 'RefactoringType', 'FilePath', 'Class',
#                   'RefactoringDetail', 'Message', 'AuthorName', 'AuthorEmail']
# df_raw['Name'].unique()  # ['hibernate$hibernate-validator', 'eclipse$bpmn2-modeler',
#                             'adangel$pmd']
df_raw.head()
# Out:
#                             Name                                  CommitId  \
# 0  hibernate$hibernate-validator  a3af1683e63c9c800f486552e7e5002c24b6712b
# 1  hibernate$hibernate-validator  6d6c3deaf0b499e06077383d8d3add43f30ba099
# 2  hibernate$hibernate-validator  6d6c3deaf0b499e06077383d8d3add43f30ba099
# 3  hibernate$hibernate-validator  25350de39ef9484997999f6e6d8f00abc5d51546
# 4  hibernate$hibernate-validator  25350de39ef9484997999f6e6d8f00abc5d51546
#
#       RefactoringType                                           FilePath  \
# 0  Move Source Folder                                                src
# 1  Move Source Folder                     hibernate-validator-legacy/src
# 2  Move Source Folder                hibernate-validator-legacy/src/test
# 3    Extract Variable  hibernate-validator/src/main/java/org/hibernat...
# 4       Rename Method  hibernate-validator/src/main/java/org/hibernat...
#
#                                            Class  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3  org.hibernate.validation.engine.ValidatorImpl
# 4  org.hibernate.validation.engine.ValidatorImpl
#
#                                    RefactoringDetail  \
# 0  Move Source Folder\tsrc to hibernate-validator...
# 1  Move Source Folder\thibernate-validator-legacy...
# 2  Move Source Folder\thibernate-validator-legacy...
# 3  Extract Variable\tleafBeanInstance : Object in...
# 4  Rename Method\tpublic getBeanConstraints() : E...
#
#                                              Message         AuthorName  \
# 0  Moved the legacy validator code into hibernate...  Hardy Ferentschik
# 1  Refactored build so that compile and test can ...  Hardy Ferentschik
# 2  Refactored build so that compile and test can ...  Hardy Ferentschik
# 3  BVAL-37 ConstraintDescriptor.getLeafValue()\n\...   Emmanuel Bernard
# 4  BVAL-37 ConstraintDescriptor.getLeafValue()\n\...   Emmanuel Bernard
#
#                 AuthorEmail
# 0  hibernate@ferentschik.de
# 1  hibernate@ferentschik.de
# 2  hibernate@ferentschik.de
# 3    emmanuel@hibernate.org
# 4    emmanuel@hibernate.org

# %%
df_raw.columns
# Out:
# Index(['Name', 'CommitId', 'RefactoringType', 'FilePath', 'Class',
#        'RefactoringDetail', 'Message', 'AuthorName', 'AuthorEmail'],
#       dtype='object')

# %%
# filter for just the adangel$pmd rows
df_adangle = df_raw[df_raw['Name'] == "adangel$pmd"]
# df_adangle.shape  # (8495, 9) same row count as reported in phase 1 report, check
df_adangle.tail()
# Out:
#               Name                                  CommitId  \
# 17312  adangel$pmd  a5f131cc4cfe59a7da3cd220353c402d3c612d76
# 17313  adangel$pmd  5a2202319f90080e9980735a37e4eb8e948d2f0f
# 17314  adangel$pmd  5a2202319f90080e9980735a37e4eb8e948d2f0f
# 17315  adangel$pmd  d43e65761ba7a58025977e9e8ed414f05e3058ce
# 17316  adangel$pmd  d43e65761ba7a58025977e9e8ed414f05e3058ce
#
#         RefactoringType                                           FilePath  \
# 17312     Rename Method  pmd-ui/src/main/java/net/sourceforge/pmd/util/...
# 17313    Extract Method  pmd-ui/src/main/java/net/sourceforge/pmd/util/...
# 17314  Rename Parameter  pmd-ui/src/main/java/net/sourceforge/pmd/util/...
# 17315      Rename Class  pmd-core/src/test/java/net/sourceforge/pmd/lan...
# 17316     Rename Method  pmd-core/src/test/java/net/sourceforge/pmd/lan...
#
#                                                    Class  \
# 17312  net.sourceforge.pmd.util.fxdesigner.popups.Eve...
# 17313  net.sourceforge.pmd.util.fxdesigner.MainDesign...
# 17314  net.sourceforge.pmd.util.fxdesigner.NodeInfoPa...
# 17315  net.sourceforge.pmd.lang.ast.xpath.AttributeAx...
# 17316  net.sourceforge.pmd.lang.ast.xpath.AttributeAx...
#
#                                        RefactoringDetail  \
# 17312  Rename Method\tprivate bindPopupToController()...
# 17313  Extract Method\tpublic onNodeItemSelected(sele...
# 17314  Rename Parameter\tfocusScopeView : boolean to ...
# 17315  Rename Class\tnet.sourceforge.pmd.lang.ast.xpa...
# 17316  Rename Method\tpublic testAttributeAxisIterato...
#
#                                                  Message        AuthorName  \
# 17312                                Fix caching logic\n  Clément Fournier
# 17313  Highlight name declarations when selecting fro...  Clément Fournier
# 17314  Highlight name declarations when selecting fro...  Clément Fournier
# 17315  [core] Undo changes to AttributeAxisIterator /...    Andreas Dangel
# 17316  [core] Undo changes to AttributeAxisIterator /...    Andreas Dangel
#
#                         AuthorEmail
# 17312  clement.fournier76@gmail.com
# 17313  clement.fournier76@gmail.com
# 17314  clement.fournier76@gmail.com
# 17315    andreas.dangel@adangel.org
# 17316    andreas.dangel@adangel.org

# %%
pd.options.display.max_rows = None
# how are file paths distributed
file_types = df_adangle['FilePath'].value_counts()
# file_types.shape  # 3139 types
file_types.head(10)
# Out:
# pmd-eclipse-plugin/plugins/net.sourceforge.pmd.eclipse.plugin/src/net/sourceforge/pmd/eclipse/ui/nls/StringKeys.java                     193
# pmd-apex/src/main/java/net/sourceforge/pmd/lang/apex/ast/AbstractApexNode.java                                                            97
# pmd/src/net/sourceforge/pmd/PMD.java                                                                                                      77
# pmd/src/net/sourceforge/pmd/ast/JavaParser.java                                                                                           75
# pmd/src/main/java/net/sourceforge/pmd/lang/plsql/ast/PLSQLParser.java                                                                     75
# pmd-java/src/main/java/net/sourceforge/pmd/lang/java/typeresolution/ClassTypeResolver.java                                                61
# pmd/src/net/sourceforge/pmd/swingui/PMDViewer.java                                                                                        58
# pmd-java/src/main/java/net/sourceforge/pmd/lang/java/ast/JavaQualifiedName.java                                                           57
# pmd-eclipse/src/net/sourceforge/pmd/eclipse/PMDPlugin.java                                                                                51
# pmd-eclipse-plugin/plugins/net.sourceforge.pmd.eclipse.plugin/src/net/sourceforge/pmd/eclipse/ui/preferences/br/RuleTableManager.java     48
# Name: FilePath, dtype: int64

# %%
# looks like some rows have multiple paths in them
df_adangle['FilePath'].iloc[230]
# Out:
# 'pmd/src/net/sourceforge/pmd/rules/ForLoopsMustUseBracesRule.java,pmd/src/net/sourceforge/pmd/rules/IfElseStmtsMustUseBracesRule.java,pmd/src/net/sourceforge/pmd/rules/WhileLoopsMustUseBracesRule.java'

# %%
# df_paths.to_csv("paths.csv", header=False, index=False)

# %%
# How many records have FilePath entries containing more than one path?
df_multi_paths = df_adangle[df_adangle['FilePath'].str.contains(',')]
# df_multi_paths.shape  # only 80, <1% so remove them
df_single_paths = df_adangle[df_adangle['FilePath'].str.contains(',') == False]
df_single_paths.reset_index(inplace=True)
# df_single_paths.shape  # 8415 = 8495 - 80, check

# %%
df_design_matrix_unparsed_filepath = df_single_paths[['RefactoringType', 'FilePath', 'AuthorName']]
df_design_matrix_unparsed_filepath.head()
# Out:
#   RefactoringType                                           FilePath  \
# 0      Move Class  pmd/src/com/infoether/pmd/ast/ASTAdditiveExpre...
# 1      Move Class  pmd/src/com/infoether/pmd/ast/ASTAllocationExp...
# 2      Move Class  pmd/src/com/infoether/pmd/ast/ASTAndExpression...
# 3      Move Class  pmd/src/com/infoether/pmd/ast/ASTArgumentList....
# 4      Move Class    pmd/src/com/infoether/pmd/ast/ASTArguments.java
#
#      AuthorName
# 0  Tom Copeland
# 1  Tom Copeland
# 2  Tom Copeland
# 3  Tom Copeland
# 4  Tom Copeland

# %% [markdown]
# ## Split the file path into columns

# %%
df_design_matrix[['L1', 'L2', 'L3', 'L4', 'L5', 'L6']] = \
df_design_matrix_unparsed_filepath['FilePath'].str.split('/', 5, expand=True)
df_design_matrix.head()
# Out:
#   RefactoringType                                           FilePath  \
# 0      Move Class  pmd/src/com/infoether/pmd/ast/ASTAdditiveExpre...
# 1      Move Class  pmd/src/com/infoether/pmd/ast/ASTAllocationExp...
# 2      Move Class  pmd/src/com/infoether/pmd/ast/ASTAndExpression...
# 3      Move Class  pmd/src/com/infoether/pmd/ast/ASTArgumentList....
# 4      Move Class    pmd/src/com/infoether/pmd/ast/ASTArguments.java
#
#      AuthorName   L1   L2   L3         L4   L5  \
# 0  Tom Copeland  pmd  src  com  infoether  pmd
# 1  Tom Copeland  pmd  src  com  infoether  pmd
# 2  Tom Copeland  pmd  src  com  infoether  pmd
# 3  Tom Copeland  pmd  src  com  infoether  pmd
# 4  Tom Copeland  pmd  src  com  infoether  pmd
#
#                                  L6
# 0    ast/ASTAdditiveExpression.java
# 1  ast/ASTAllocationExpression.java
# 2         ast/ASTAndExpression.java
# 3          ast/ASTArgumentList.java
# 4             ast/ASTArguments.java

# %%
# how many instances at each level?
# df_design_matrix['L1'].value_counts().shape  # 95 at the top level, but 41 singletons
df_design_matrix['L1'].value_counts()
# Out:
# pmd                                                              4024
# pmd-eclipse-plugin                                               1073
# pmd-java                                                          994
# pmd-core                                                          641
# pmd-ui                                                            283
# pmd-apex                                                          255
# pmd-eclipse                                                       234
# pmd-jerry                                                          90
# pmd-eclipse-ui                                                     88
# pmd-visualforce                                                    77
# pmd-netbeans                                                       62
# pmd-dcpd                                                           61
# pmd-jedit                                                          59
# pmd-xml                                                            53
# pmd-jbuilder                                                       48
# pmd-jdeveloper.11.1.1                                              28
# pmd-jdeveloper.09.0.5-10.1.2                                       27
# pmd-jdeveloper.10.1.3                                              20
# pmd-doc                                                            20
# pmd-plsql                                                          18
# pmd-eclipse-test                                                   17
# pmd-jdeveloper                                                     17
# pmd-javascript                                                     16
# pmd-test                                                           15
# pmd-jdeveloper.11.1.2                                              15
# pmd-vm                                                             13
# pmd-jdeveloper1013                                                 13
# pmd-eclipse-runtime                                                12
# pmd-gel                                                            11
# pmd-swingui                                                        11
# pmd-jsp                                                             9
# pmd-dist                                                            8
# pmd-cpp                                                             7
# net.sourceforge.pmd.rules                                           7
# pmd-swift                                                           4
# pmd-java8                                                           3
# pmd-python                                                          3
# pmd-cs                                                              3
# pmd-eclipse-pmd                                                     3
# net.sourceforge.pmd.lang.java.rule.basic                            3
# net.sourceforge.pmd.lang.vm.rule.basic                              3
# maven-plugin-pmd-build                                              3
# net.sourceforge.pmd.parsers                                         3
# net.sourceforge.pmd.lang.java.rule.unnecessary                      2
# net.sourceforge.pmd.lang.java.oom                                   2
# net.sourceforge.pmd.lang.java.metrics                               2
# net.sourceforge.pmd.lang.java.rule.naming                           2
# net.sourceforge.pmd.lang.java.rule.optimizations                    2
# net.sourceforge.pmd.lang.java.rule.logging                          2
# net.sourceforge.pmd.lang.java.rule.strings                          2
# net.sourceforge.pmd.lang.apex.rule.style                            2
# net.sourceforge.pmd.eclipse                                         2
# net.sourceforge.pmd.lang.java.rule.imports                          1
# pmd-objectivec                                                      1
# net.sourceforge.pmd.lang.java.rule.clone                            1
# net.sourceforge.pmd.lang.java.rule.codesize                         1
# net.sourceforge.pmd.lang.java.rule.unusedcode                       1
# net.sourceforge.pmd.lang.java.rule.comments                         1
# net.sourceforge.pmd.lang.java.rule.controversial                    1
# net.sourceforge.pmd.lang.java.rule.coupling                         1
# net.sourceforge.pmd.lang.plsql.rule.codesize                        1
# net.sourceforge.pmd.lang.apex.rule.complexity                       1
# pmd-matlab                                                          1
# net.sourceforge.pmd.ruleset                                         1
# net.sourceforge.pmd.lang.java.rule.junit                            1
# net.sourceforge.pmd.lang.java.rule.sunsecure                        1
# net.sourceforge.pmd.lang.java.rule.typeresolution.xml               1
# net.sourceforge.pmd.lang.java.rule.strictexception                  1
# net.sourceforge.pmd.lang.apex.rule.apexunit                         1
# pmd-jedeveloper.09.0.5-10.1.2                                       1
# pmd-rx                                                              1
# test.net.sourceforge.pmd.rules.finalize                             1
# pmd-eclipse-test-fragment                                           1
# net.sourceforge.pmd.sourcetypehandlers                              1
# net.sourceforge.pmd.jsp.rules                                       1
# net.sourceforge.pmd.jaxen                                           1
# net.sourceforge.pmd.dfa.variableaccess                              1
# test.net.sourceforge.pmd.jsp.rules                                  1
# test.net.sourceforge.pmd.rules                                      1
# test.net.sourceforge.pmd.rules.optimization                         1
# test.net.sourceforge.pmd.rules.logging.java                         1
# test.net.sourceforge.pmd.rules.logging.jakartacommons               1
# test.net.sourceforge.pmd.eclipse                                    1
# net.sourceforge.pmd.lang.java.metrics.metrics                       1
# net.sourceforge.pmd.lang.apex.rule.basic                            1
# net.sourceforge.pmd.lang.apex.rule.codesize                         1
# net.sourceforge.pmd.lang.apex.rule.design                           1
# net.sourceforge.pmd.lang.apex.rule.naming                           1
# pmd-groovy                                                          1
# pmd-jdeveloper.9.0.5-10.1.2                                         1
# net.sourceforge.pmd.lang.java.oom.keys                              1
# net.sourceforge.pmd.lang.java.oom.interfaces                        1
# net.sourceforge.pmd.lang.java.oom.metrics.cyclo                     1
# net.sourceforge.pmd.lang.java.typeresolution.typeinterference       1
# net.sourceforge.pmd.lang.java.oom.visitor                           1
# Name: L1, dtype: int64

# %%
# df_design_matrix['L2'].value_counts().shape  # 16 at the 2nd level
df_design_matrix['L2'].value_counts()
# Out:
# src                                                 6535
# plugins                                             1003
# regress                                              596
# test-data                                             42
# PMDPlugin                                             39
# pmd-eclipse-ui                                        28
# pmd-eclipse-test                                      22
# test                                                  20
# net.sourceforge.pmd.eclipse.plugin                     9
# tools                                                  8
# pmd-eclipse-runtime                                    7
# tool                                                   1
# pmd-eclipse-pmd                                        1
# pmd-eclipse-test-fragment                              1
# net.sourceforge.pmd.eclipse.plugin.test.fragment       1
# net.sourceforge.pmd.eclipse.plugin.test                1
# Name: L2, dtype: int64

# %%
# df_design_matrix['L3'].value_counts().shape  # 47 at the 3rd level, but only the top 7 look relevant
df_design_matrix['L3'].value_counts()
# Out:
# net                                    3232
# main                                   2429
# test                                   1347
# net.sourceforge.pmd.eclipse.plugin     1002
# com                                      99
# src                                      87
# pmd                                      62
# IfStmtsMustUseBraces2.java                2
# UnusedPrivateInstanceVar17.java           2
# java                                      1
# UnusedLocal15.java                        1
# UnusedLocal1.java                         1
# UnusedLocal10.java                        1
# UnusedLocal11.java                        1
# UnusedLocal12.java                        1
# UnusedLocal13.java                        1
# UnusedLocal14.java                        1
# UnusedLocal2.java                         1
# OverrideBothEqualsAndHashcode4.java       1
# UnusedLocal3.java                         1
# AvoidStringLiterals3.java                 1
# UnusedLocal6.java                         1
# UnusedLocal7.java                         1
# UnusedLocal8.java                         1
# UnusedLocal9.java                         1
# UnusedLocal5.java                         1
# AvoidStringLiterals1.java                 1
# UnusedPrivateInstanceVar1.java            1
# UnusedPrivateInstanceVar9.java            1
# UnusedPrivateInstanceVar10.java           1
# UnusedPrivateInstanceVar11.java           1
# UnusedPrivateInstanceVar12.java           1
# UnusedPrivateInstanceVar13.java           1
# UnusedPrivateInstanceVar14.java           1
# UnusedPrivateInstanceVar15.java           1
# UnusedPrivateInstanceVar16.java           1
# UnusedPrivateInstanceVar18.java           1
# UnusedPrivateInstanceVar19.java           1
# UnusedPrivateInstanceVar2.java            1
# UnusedPrivateInstanceVar20.java           1
# UnusedPrivateInstanceVar3.java            1
# UnusedPrivateInstanceVar4.java            1
# UnusedPrivateInstanceVar5.java            1
# UnusedPrivateInstanceVar6.java            1
# UnusedPrivateInstanceVar7.java            1
# ContainsSystemGetProps.java               1
# UnusedPrivateInstanceVar8.java            1
# Name: L3, dtype: int64

# %%
# df_design_matrix['L4'].value_counts().shape  # 16 at the 4th level, only 4 singletons
df_design_matrix['L4'].value_counts()
# Out:
# sourceforge               3232
# java                      3136
# src                       1001
# net                        699
# infoether                   99
# config                      34
# RunPMDAction.java           12
# scan                        10
# com                          7
# main                         7
# resources                    6
# PMDOutputListener.java       3
# Fault.java                   1
# custom                       1
# OutputWindow.java            1
# test                         1
# Name: L4, dtype: int64

# %%
# df_design_matrix['L5'].value_counts().shape  # 14 at the 5th level, only 3 singletons
df_design_matrix['L5'].value_counts()
# Out:
# net                                3948
# pmd                                3331
# sourceforge                         699
# test                                195
# ui                                   31
# infoether                             7
# java                                  7
# Scanner.java                          6
# EditorChangeListener.java             2
# ConfigUtils.java                      2
# PMDScanAnnotation.java                2
# PMDOptionsSettingsBeanInfo.java       1
# RuleClassLoader.java                  1
# ApexParserTest.java                   1
# Name: L5, dtype: int64

# %%
df_design_matrix.to_csv("df_design_matrix.csv", header=True, index=False)
